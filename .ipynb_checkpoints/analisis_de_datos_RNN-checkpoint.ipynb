# %% [markdown]
# <h1>US Airlinesentiment analysisusing twitter data.Vivek Yadav, PhD</h1>
#
# <br>
# Data
# 14640 tweets from 7700 users were analyzed. Twitter data was scraped from February of 2015
# and contributors were asked to first classify positive, negative, and neutral tweets,
# followed by categorizing negative reasons (such as "late flight" or "rude service").

# %% [markdown]
# Columns name
# <ul>
#     <li>tweet_id</li>
#     <li>airline_sentiment</li>
#     <li>airline_sentiment_confidence</li>
#     <li>negativereason</li>
#     <li>negativereason_confidence</li>
#     <li>airline</li>
#     <li>airline_sentiment_gold</li>
#     <li>name</li>
#     <li>negativereason_gold</li>
#     <li>retweet_count</li>
#     <li>tweet_coord</li>
#     <li>tweet_created</li>
#     <li>tweet_location</li>
#     <li>user_timezone</li>
#
# </ul>
# <br>
# <p><a href="http://vxy10.github.io/p6_vis_versions/scroll_Submission1/index.html"><strong>Landing summary</strong></a></p>
# <p><a href="https://www.kaggle.com/crowdflower/twitter-airline-sentiment"><strong>Data</strong></a></p>
#
# <p><a href="https://medium.com/@francesca_lim/twitter-u-s-airline-sentiment-analysis-using-keras-and-rnns-1956f42294ef"><strong>Medium</strong></a></p>
#
# <p><a href="https://www.kaggle.com/parthsharma5795/comprehensive-twitter-airline-sentiment-analysis/comments#548445"><strong>LINK 1</strong></a></p>
#
# <p><a href="https://www.kaggle.com/welkin10/airline-sentiment-analysis"><strong>LINK 2</strong></a></p>
#
#
# <p><a href="https://www.kaggle.com/parthsharma5795/comprehensive-twitter-airline-sentiment-analysis"><strong>LINK 3</strong></a></p>
#
#
# <p><a href="https://www.kaggle.com/wesleyliao3/sentiment-analysis-using-rnn-lstm-ulmfit"><strong>LINK 4</strong></a></p>
#
#
# <p><a href="https://www.kaggle.com/anjanatiha/sentiment-analysis-with-lstm-cnn"><strong>LINK 5</strong></a></p>
#
# <p><a href="https://github.com/frlim/data2040_final/blob/master/project_1/final_notebook.ipynb"><strong>github</strong></a></p>

# %% [markdown]
# <div style="text-align: center">
# <h2><font color="#004D7F" size=6>Análisis y Procesamiento de datos</font></h2>
# <h1></h1>
#
# <div style="text-align: center">
# <font color="#004D7F" size=5>Curso: Inteligencia Artificial</font><br>
# <font color="#004D7F" size=5>Docente: Juan Villegas Cubas</font><br>
#     <font color="#004D7F" size=5>Alumno: Gonzalo López Guerrero</font><br>
#
# <br><br>
# <div style="text-align: right">
# <font color="#004D7F" size=3>Octubre 2020</font><br>

# %% [markdown]
# <a id="section11"></a>
# ## <font color="#004D7F">Cargar el conjunto de datos</font>

# %%
import pandas as pd
import numpy as np
import re
# %matplotlib inline
import plotly 
from wordcloud import WordCloud,STOPWORDS
import seaborn as sns
import matplotlib.pyplot as plt

#import twitter data
filename = '../Data/Tweets.csv'
dataset = pd.read_csv(filename)
print(dataset.shape)#rows x columns
# Out:
# (14441, 15)

# %%
# Permite ajustar la anchura de la parte útil de la libreta (reduce los márgenes)
from IPython.core.display import display, HTML
display(HTML("<style>.container{ width:90% }</style>"))
# Out:
# <style>.container{ width:90% }</style>

# %% [markdown]
# <a id="section12"></a>
# ## <font color="#004D7F">Revisar los datos: _head()_ </font>

# %%
dataset.head(10)
# Out:
#        tweet_id  airline_sentiment_confidence          negativereason  \
# 0  5.692630e+17                        1.0000                     NaN
# 1  5.692620e+17                        1.0000  Customer Service Issue
# 2  5.692610e+17                        1.0000                     NaN
# 3  5.692610e+17                        0.6809                     NaN
# 4  5.692610e+17                        1.0000                     NaN
# 5  5.692530e+17                        1.0000                     NaN
# 6  5.692530e+17                        1.0000                     NaN
# 7  5.692500e+17                        0.6775                     NaN
# 8  5.692480e+17                        1.0000                     NaN
# 9  5.692480e+17                        1.0000                     NaN
#
#    negativereason_confidence         airline airline_sentiment_gold  \
# 0                        NaN  Virgin America                    NaN
# 1                     0.6733  Virgin America                    NaN
# 2                        NaN  Virgin America                    NaN
# 3                     0.0000  Virgin America                    NaN
# 4                        NaN  Virgin America                    NaN
# 5                        NaN  Virgin America                    NaN
# 6                        NaN  Virgin America                    NaN
# 7                     0.0000  Virgin America                    NaN
# 8                        NaN  Virgin America                    NaN
# 9                        NaN  Virgin America                    NaN
#
#               name negativereason_gold  retweet_count  \
# 0        JT_Magana                 NaN              0
# 1    MaximWheatley                 NaN              0
# 2        carabubes                 NaN              0
# 3        carabubes                 NaN              0
# 4          wmrrock                 NaN              0
# 5   DailyBillboard                 NaN              0
# 6  BigRichTexasPam                 NaN              0
# 7             rtw4                 NaN              0
# 8      casualdiego                 NaN              0
# 9    kyle_romanoff                 NaN              0
#
#                                                 text  \
# 0  @VirginAmerica I love your guy's song! We're d...
# 1  @VirginAmerica Your website is down and I'm tr...
# 2  @VirginAmerica done! Thank you for the quick r...
# 3  @VirginAmerica nervous about my flight from DC...
# 4  @VirginAmerica cool picture of another VirginA...
# 5           @VirginAmerica Keep up the great work :)
# 6  @VirginAmerica my goodness your people @love f...
# 7  @VirginAmerica Thanks for a great flight from ...
# 8  @VirginAmerica can you please get me to the ne...
# 9  @VirginAmerica Thanks so much for the awesome ...
#
#                    tweet_coord     tweet_created            tweet_location  \
# 0                          NaN  02/21/2015 14:28                       NaN
# 1                          NaN  02/21/2015 14:27            Washington, DC
# 2                          NaN  02/21/2015 14:24   Los Angeles, California
# 3                          NaN  02/21/2015 14:23   Los Angeles, California
# 4                          NaN  02/21/2015 14:21                        CT
# 5                          NaN  02/21/2015 13:52   Los Angeles, California
# 6  [32.84359605, -96.84910929]  02/21/2015 13:52             FREE ADVICE!
# 7                          NaN  02/21/2015 13:41           Natick, MA, USA
# 8                          NaN  02/21/2015 13:32  okayville, population me
# 9                          NaN  02/21/2015 13:32                       NaN
#
#                 user_timezone airline_sentiment
# 0                         NaN          positive
# 1      Atlantic Time (Canada)          negative
# 2  Central Time (US & Canada)          positive
# 3  Central Time (US & Canada)           neutral
# 4  Eastern Time (US & Canada)          positive
# 5  Pacific Time (US & Canada)          positive
# 6  Central Time (US & Canada)          positive
# 7  Central Time (US & Canada)          positive
# 8                         NaN           neutral
# 9                         NaN          positive

# %%
dataset[['text','airline_sentiment']].head(10)
# Out:
#                                                 text airline_sentiment
# 0  @VirginAmerica I love your guy's song! We're d...          positive
# 1  @VirginAmerica Your website is down and I'm tr...          negative
# 2  @VirginAmerica done! Thank you for the quick r...          positive
# 3  @VirginAmerica nervous about my flight from DC...           neutral
# 4  @VirginAmerica cool picture of another VirginA...          positive
# 5           @VirginAmerica Keep up the great work :)          positive
# 6  @VirginAmerica my goodness your people @love f...          positive
# 7  @VirginAmerica Thanks for a great flight from ...          positive
# 8  @VirginAmerica can you please get me to the ne...           neutral
# 9  @VirginAmerica Thanks so much for the awesome ...          positive

# %% [markdown]
# <a id="section13"></a>
# ## <font color="#004D7F">Tipo de datos: _dtypes_ </font>

# %%
dataset.dtypes
# Out:
# tweet_id                        float64
# airline_sentiment_confidence    float64
# negativereason                   object
# negativereason_confidence       float64
# airline                          object
# airline_sentiment_gold           object
# name                             object
# negativereason_gold              object
# retweet_count                     int64
# text                             object
# tweet_coord                      object
# tweet_created                    object
# tweet_location                   object
# user_timezone                    object
# airline_sentiment                object
# dtype: object

# %%
#dataset[['airline_sentiment_confidence','negativereason_confidence']].describe()

# %% [markdown]
# <a id="section15"></a>
# ## <font color="#004D7F">Distribución entre clases: _groupby('class').size()_ </font>

# %%
dataset.groupby('airline_sentiment').size() #count for class
# Out:
# airline_sentiment
# negative    9095
# neutral     3034
# positive    2312
# dtype: int64

# %%
#dataset[['airline_sentiment_confidence','negativereason_confidence']].corr(method='pearson')

# %% [markdown]
# <a id="section21"></a>
# ## <font color="#004D7F">Histogramas </font>

# %%
figsize=(20, 5)

ticksize = 14
titlesize = ticksize + 8
labelsize = ticksize + 5

params = {'figure.figsize' : figsize,
          'axes.labelsize' : labelsize,
          'axes.titlesize' : titlesize,
          'xtick.labelsize': ticksize,
          'ytick.labelsize': ticksize}

plt.rcParams.update(params)

plt.subplot(121)
col = "airline"
xlabel = "Airlines"
ylabel = "Count"

sns.countplot(x=dataset[col])
plt.title("Airlines Review Count")
plt.xticks(rotation=90)
plt.xlabel(xlabel)
plt.ylabel(ylabel)


plt.subplot(122)
col = "airline_sentiment"
xlabel = "Sentiment"
ylabel = "Count"
sns.countplot(dataset[col])
plt.title("Review Sentiment Count")
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.xticks(rotation=90)
plt.plot()
# Out:
# []

# %% [markdown]
# <ul>
# <li>La mayoria de los tweets son de caracter negativo</li>
# <br>
# <li>La mayoria de los tweets son de las aerolineas :"United", "US Airlines" and "American Airlines"</li>
# </ul>

# %% [markdown]
# <br>
# <h2><strong>El razon negativa que más se repite es "Customer Service Issue"</strong></h2>

# %%
figsize=(20, 5)

ticksize = 14
titlesize = ticksize + 8
labelsize = ticksize + 5

xlabel = "Negative Reason"
ylabel = "Count"

title = "Negative Reason Per Airlines"


params = {'figure.figsize' : figsize,
          'axes.labelsize' : labelsize,
          'axes.titlesize' : titlesize,
          'xtick.labelsize': ticksize,
          'ytick.labelsize': ticksize}

plt.rcParams.update(params)

col1 = "negativereason"
col2 = "airline"
sns.countplot(x=dataset[col1], hue=dataset[col2])
plt.title(title)
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.xticks(rotation=90)
plt.plot()
# Out:
# []

# %% [markdown]
# <br>
# <h2>Clase de tweet que más se repite en cada aereolinea</h2>

# %%
dataset.groupby(['airline', 'airline_sentiment']).size().unstack().plot(kind='bar', stacked=True)

# %% [markdown]
# <a id="section21"></a>
# ## <font color="#004D7F">Palabra más usadas</font>

# %%
dataset['negativereason'].value_counts()
# Out:
# Customer Service Issue         2884
# Late Flight                    1654
# Can't Tell                     1178
# Cancelled Flight                837
# Lost Luggage                    723
# Bad Flight                      576
# Flight Booking Problems         516
# Flight Attendant Complaints     478
# longlines                       177
# Damaged Luggage                  72
# Name: negativereason, dtype: int64

# %%
# Clean tweets beforehand to improve word cloud, remove user handles, stop words, word less than 3 characters, etc
# Code from:
# https://www.analyticsvidhya.com/blog/2018/07/hands-on-sentiment-analysis-dataset-python/
def remove_pattern(input_txt, pattern):
    r = re.findall(pattern, input_txt)
    for i in r:
        input_txt = re.sub(i, '', input_txt)
        
    return input_txt

# %%
# remove twitter handles (@user)
dataset['tidy_tweet'] = np.vectorize(remove_pattern)(dataset['text'], "@[\w]*")
# remove special characters, numbers, punctuations
dataset['tidy_tweet'] = dataset['tidy_tweet'].str.replace("[^a-zA-Z#]", " ")
# remove words less than 3 characters long
dataset['tidy_tweet'] = dataset['tidy_tweet'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>3]))
dataset['tidy_tweet']
# Out:
# 0           love your song dancing high school dance revue
# 1                           Your website down trying check
# 2        done Thank quick response apparently faster th...
# 3        nervous about flight from getting Cancelled Fl...
# 4        cool picture another VirginAmerica plane wing ...
#                                ...
# 14436                       thank different flight Chicago
# 14437    leaving over minutes Late Flight warnings comm...
# 14438           Please bring American Airlines #BlackBerry
# 14439    have money change flight answer your phones ot...
# 14440    have need know many seats next flight standby ...
# Name: tidy_tweet, Length: 14441, dtype: object

# %%
# Stopwords are English words that do not add much meaning to the sentence
comment_words = ' '
stopwords = set(STOPWORDS)

# %%
# Create 3 separate dataframes only containing either positive, negative, or neutral tweets
# Positive
pos_df = dataset[dataset['airline_sentiment']=='positive']

# Negative
neg_df = dataset[dataset['airline_sentiment']=='negative']

# Neutral
neu_df = dataset[dataset['airline_sentiment']=='neutral']

# %% [markdown]
# <h3>Palabras Positivas</h3>

# %%
# Positive wordcloud
wordcloud = WordCloud(
                    background_color='white',
                    stopwords=stopwords,
                    max_words=75,
                    max_font_size=40,
                    random_state=42).generate(str(pos_df['tidy_tweet']))
 
print(wordcloud)
fig = plt.figure(1, figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x0000017E2CE28E20>

# %% [markdown]
# <h3>Palabras Negativas</h3>

# %%
# Negative wordcloud
wordcloud = WordCloud(
                    background_color='white',
                    stopwords=stopwords,
                    max_words=75,
                    max_font_size=40,
                    random_state=42).generate(str(neg_df['tidy_tweet']))
 
print(wordcloud)
fig = plt.figure(1, figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x0000017E2DFAB790>

# %% [markdown]
# <h3>Palabras Neutral</h3>

# %%
# Neutral 
wordcloud = WordCloud(
                    background_color='white',
                    stopwords=stopwords,
                    max_words=75,
                    max_font_size=40,
                    random_state=42).generate(str(neu_df['tidy_tweet']))
 
print(wordcloud)
fig = plt.figure(1, figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x0000017E2E2EC100>

# %% [markdown]
# <a id="section33"></a>
# ## <font color="#004D7F">Matriz de dispersion por clase </font>

# %%
sns.pairplot(dataset[['airline_sentiment_confidence',
                      'negativereason_confidence',
                      'airline_sentiment']],
             hue="airline_sentiment", 
             diag_kind="hist",
             height=5)
